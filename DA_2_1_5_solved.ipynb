# %% [markdown]
# # Module: Communicating Analysis Results
# ## Sprint: Visualising Data using Looker Studio
# ## Part 5: Graded exercise
#
# Tips and example of project solution can be found [here](https://docs.google.com/document/d/1tSwxCL6bGmci4eCoN63QC6tDAex8y111cuOSFVSIlOc/edit?usp=sharing)
