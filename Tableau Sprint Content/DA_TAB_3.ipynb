# %% [markdown]
# # Module: Communicating Analysis Results
# ## Sprint: Visualising Data using Tableau
# ## Part 3: Bringing your dashboards to next level
#
# [Storytelling with Data: A Data Visualization Guide for Business Professionals](https://learning.oreilly.com/library/view/storytelling-with-data/9781119002253/)
# - Chapter 7-8
#
# [Year over Year calculations](https://kb.tableau.com/articles/howto/creating-year-over-year-ytd-comparison)
# [Tableau Dashboards Sharing Options](https://www.youtube.com/watch?v=QDfTZ1HCvhM)
#
#
# ## Optional Resources
# If you struggle with understanding difference between Exploratory and Explanatory analysis:
# https://www.storytellingwithdata.com/blog/2014/04/exploratory-vs-explanatory-analysis
#
# [Learning Tableau 2022 - Fifth Edition by Joshua N. Milligan](https://learning.oreilly.com/library/view/learning-tableau-2022/9781801072328/)
# - Chapter 1-11
#
# [Data Visualization with Tableau](https://learning.oreilly.com/videos/data-visualization-with/9781788837330/) (Course in O’Reilly, approx 3-4 hours).
# - Chapter 3 : Creating Basic Charts and Graphs
# - Chapter 4 : Data Management
# - Chapter 5 : Working with Dates
# - Chapter 6 : Table Calculation
# - Chapter 7 : Advanced Chart Forms
#
# ## Advanced Dashboard Examples:
#
# [Tableau’s Viz of the day](https://www.tableau.com/blog/viz-day-heres-what-you-need-know)
#
# [Real-World Examples of BI Dashboards](https://www.tableau.com/learn/articles/business-intelligence-dashboards-examples)
#
# [7 Great Examples & Templates of Sales Dashboards](https://www.tableau.com/learn/articles/sales-dashboards-examples-and-templates)
